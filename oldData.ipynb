# %%
import pandas as pd
import numpy as np

# %%
PersonalInfo = pd.read_csv('./MainData.csv')
CommonData = pd.read_csv('./CommonData.csv')

# %%
OldPersonal = pd.read_excel('oldData.xlsx', sheet_name='Individual data')
OldCommon = pd.read_excel('oldData.xlsx', sheet_name='Family Data')

# %%
OldPersonal = OldPersonal.replace({'No': 'NO', np.nan : pd.NA, 'N/A': pd.NA, 'Yes': 'YES'})

# %%
OldPersonal
# Out:
#           Unique ID  S.No         Name Birth Date  Gender     Qualification  \
# 0   IRNCEPGPF001I01     1    Jayapriya 2001-11-19  Female  Higher secondary
# 1   IRNCEPGPF001I02     2   Arul Kumar 1994-07-29    Male         Secondary
# 2   IRNCEPGPF001I03     3     Saswanth 2020-07-12    Male              <NA>
# 3   IRNCEPGPF001I04     4       Sindhu 2003-02-02  Female  Higher secondary
# 4   IRNCEPGPF001I05     5   Mahalingan 1991-08-03    Male  Higher secondary
# ..              ...   ...          ...        ...     ...               ...
# 56  IRNCEPGPF014I01    57    Sakthivel 1975-05-05    Male        Uneducated
# 57  IRNCEPGPF014I02    58  Poovaththal 1955-10-15  Female        Uneducated
# 58  IRNCEPGPF015I01    59       Dinesh 1998-11-10    Male     Post graduate
# 59  IRNCEPGPF015I02    60   Palanisamy 1976-05-12    Male        Uneducated
# 60  IRNCEPGPF015I03    61      Lakshmi 1976-05-10  Female        Uneducated
#
#     Phone Number  Aadhar Number          Vulnerabilities  \
# 0     8015573221              1         Lactating mother
# 1     8807628958              2                     None
# 2              0              3    Children below 2years
# 3              0              4         Lactating mother
# 4              0              5                     None
# ..           ...            ...                      ...
# 56             0             49                     None
# 57             0             50  Elderly >60 years,Widow
# 58             0             51                     None
# 59             0   877561384818                     None
# 60             0   785417604575                     None
#
#                           Occupation  ...  Surgeries Anganawadi services  \
# 0                         Unempolyed  ...         NO               AWARE
# 1   Craft and related trades workers  ...         NO           NOT AWARE
# 2                               <NA>  ...         NO               AWARE
# 3                         Unemployed  ...         NO               AWARE
# 4             Elementary occupations  ...         NO           NOT AWARE
# ..                               ...  ...        ...                 ...
# 56            Elementary occupations  ...         NO           NOT AWARE
# 57                        Unempolyed  ...         NO           NOT AWARE
# 58                          Managers  ...         NO           NOT AWARE
# 59            Elementary occupations  ...         NO           NOT AWARE
# 60            Elementary occupations  ...         NO           NOT AWARE
#
#    Anganwadi services utilised  Public health centers Private health centers  \
# 0               Dry Ration,THR                     NO    Primary health care
# 1                         <NA>                     NO    Primary health care
# 2               Dry Ration,THR                     NO    Primary health care
# 3               Dry Ration,THR                     NO    Primary health care
# 4                         <NA>                     NO    Primary health care
# ..                         ...                    ...                    ...
# 56                        <NA>                     NO    Primary health care
# 57                        <NA>                     NO    Primary health care
# 58                        <NA>                     NO    Primary health care
# 59                        <NA>                     NO                     NO
# 60                        <NA>                     NO                     NO
#
#    Reason for using private health centers Tobacco based Products  \
# 0                           Short distance                   <NA>
# 1                           Short distance                   Hans
# 2                           Short distance                   <NA>
# 3                           Short distance                   <NA>
# 4                           Short distance                   <NA>
# ..                                     ...                    ...
# 56                          Short distance                  Beedi
# 57                          Short distance             Betel nuts
# 58                        Better treatment                   <NA>
# 59                                      NO                  Beedi
# 60                                      NO             Betel nuts
#
#    Consume  alcohol Arogya sethu App Vizhithiri App
# 0                NO               NO             NO
# 1               YES               NO             NO
# 2                NO               NO             NO
# 3                NO               NO             NO
# 4                NO               NO             NO
# ..              ...              ...            ...
# 56               NO               NO             NO
# 57               NO               NO             NO
# 58               NO               NO             NO
# 59               NO               NO             NO
# 60               NO               NO             NO
#
# [61 rows x 31 columns]
